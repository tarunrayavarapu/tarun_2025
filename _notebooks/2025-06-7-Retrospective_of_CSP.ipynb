# %% [raw]
# ---
# layout: post
# title: Retrospective of CSP
# description:  Reflection
# type: issues
# comments: true
# ---

# %% [markdown]
# # Final Retrospective: My AP CSP Journey
# *June 9, 2025 • 7 min read*
#
# ---
#
# ## The Open Coding Society Vision: Credentials with Purpose
#
# In AP CSP, I participated in the **Open Coding Society**, where learning went beyond grades — it became about real projects, mastery, and creativity:
#
# - **Certificates (fungible)** = verified mastery of coding tools and frameworks
# - **NFTs (non-fungible)** = one-of-a-kind contributions and innovations
#
# I earned all of the following through my projects, demos, and collaboration.
#
# ---
#
# ## CSP Certificates (Fungible Microcredentials)
#
# | Certificate             | Description                                                |
# |:-----------------------|:-----------------------------------------------------------|
# | GitHub Pages            | Deployed personal sites using custom domains and Markdown  |
# | Flask Framework         | Created REST APIs and backend systems for dynamic apps     |
# | SQLite                  | Managed and queried data in projects like my predictors    |
# | Pandas                  | Processed data for prediction models and APIs              |
# | Postman                 | Tested API routes and integrations                         |
# | Python                  | Wrote backend logic, ML models, and API endpoints          |
# | HTML & CSS              | Designed responsive, styled interfaces                     |
# | JavaScript DOM          | Made interactive UIs like live ratings and riddles         |
# | JSON & YAML             | Configured metadata for APIs and prediction outputs        |
# | REST API Design         | Built modular APIs for multiple apps                       |
# | API Integration         | Connected AI features and external APIs                    |
# | Git Version Control     | Branching, committing, and collaborating via GitHub        |
# | VS Code & Terminal      | Managed local dev environments and debugging               |
# | Deployment & Hosting    | Hosted apps via GitHub Pages and AWS Cockpit               |
# | Data Validation         | Verified user inputs and API requests                      |
# | MVC Structure           | Structured frontend-backend communication cleanly         |
# | Tailwind CSS            | Styled fast, responsive UIs for my apps                    |
# | LocalStorage            | Stored user preferences and data client-side               |
#
# **Total:** 18 unique CSP Certificates earned through hands-on projects
#
# ---
#
# ## NFTs: My Non-Fungible Contributions to CSP
#
# These aren’t just features — they’re creative moments only I could’ve built:
#
# | NFT Title             | Description                                                    |
# |:---------------------|:---------------------------------------------------------------|
# | **The Predictor Prodigy** | Created a dual Grade & AP Exam Predictor to help students track academic success through smart, data-driven insights |
# | **The Travel Architect** | Built InterTravel, a full-stack travel planner with live ratings, chatbot, and price estimator |
# | **The Social Strategist** | Developed a social media predictor for Palomar Health, forecasting post engagement trends |
# | **The Riddle Master** | Designed a multiplayer riddle game with real-time answer validation and feedback |
# | **The Full-Stack Visionary** | Integrated frontends with custom REST APIs, prediction models, and dynamic UI components |
# | **The Deployment Champ** | Deployed multiple full-stack apps with live URLs using GitHub Pages and AWS Cockpit |
# | **The AI Integrator** | Added AI-powered chat and prediction features for smarter, interactive apps |
# | **The Team Navigator** | Led and coordinated project groups through Agile practices and live demos |
#
# ---
#
# ## What I Built
#
# ### 📊 Grade Predictor / AP Exam Predictor
# - **Features:** Predicts final grades and AP scores using academic trends
# - **User Page:** Displays live predictions based on user input
# - **Skills Used:** Python, Pandas, Flask, SQLite, REST API Design, Tailwind
# - **Credentials Earned:**
#   - Predictor Prodigy NFT
#   - Python, Flask, Pandas, SQLite, API Design, Tailwind, Deployment Certificates
#
# ---
#
# ### 🗺️ InterTravel
# - **Features:** Trip planner with hotel prices, activity planner, travel chatbot, and real-time ratings
# - **Skills Used:** Flask, JavaScript DOM, SQLite, LocalStorage, AWS Cockpit
# - **Credentials Earned:**
#   - Travel Architect NFT
#   - Flask, SQLite, JavaScript DOM, LocalStorage, Tailwind, Deployment Certificates
#
# ---
#
# ### 📱 Palomar Health Social Media Predictor
# - **Features:** Predicts social media post engagement based on post type, timing, and topic
# - **Skills Used:** Python, Pandas, Flask, Postman, Tailwind CSS
# - **Credentials Earned:**
#   - Social Strategist NFT
#   - Python, Pandas, Flask, Postman, Tailwind Certificates
#
# ---
#
# ### 🧩 Riddle Room
# - **Features:** Gamified puzzle platform where users solve riddles in sequence
# - **Skills Used:** Flask, JavaScript, HTML, CSS, LocalStorage
# - **Credentials Earned:**
#   - Riddle Master NFT
#   - Flask, JavaScript DOM, HTML/CSS, LocalStorage Certificates
#
# ---
#
# ## CSP Performance Summary
#
# - Submitted every assignment, reflection, and milestone on time
# - Deployed 4 major full-stack projects
# - Led demos and live walkthroughs of apps to peers
# - Applied Agile practices with Scrum standups, backlog grooming, and iterative updates
# - Integrated AI and external APIs for advanced app features
# - Logged daily GitHub commits
#
# ---
#
# ## HyFlex: Education Evolved
#
# This class let me:
#
# - Take on different project roles — from Scrum leader to full-stack dev
# - Blend independent work with group projects
# - Learn real-world tools like Flask, Pandas, SQLite, and Tailwind through experience
# - Build apps that made a difference for students, users, and real organizations
#
# ---
#
# ## 5 Takeaways from CSP
#
# 1. **Debugging is a superpower** — patience and strategy are just as important as syntax.
# 2. **Presentation matters** — showing off your work clearly is half the impact.
# 3. **Collaboration multiplies creativity** — clear roles and communication build stronger apps.
# 4. **Teaching strengthens skills** — explaining features like AI APIs made me a better dev.
# 5. **Document everything** — blogging turns projects into a living resume of what you can do.
#
# ---
#
# ## Final Reflection
#
# This class didn’t just teach me to code — it taught me to **build, share, and lead**. And this blog is my proof.
