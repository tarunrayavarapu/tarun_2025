# %% [raw]
# ---
# layout: post
# title: Study Guide
# description:  Reflection
# type: issues
# comments: true
# ---

# %% [markdown]
# ---
#
# ## 🧠 Big Idea 1: Creative Development
#
# | Topic                         | What to Practice |
# |------------------------------|------------------|
# | 1.1 Collaboration            | Practice writing team comments & describing team roles in a Create PT-style prompt. |
# | 1.2 Program Function/Purpose | Describe the purpose of sample code & identify inputs/outputs in practice questions. |
# | 1.3 Program Design           | Make a flowchart for a simple algorithm & trace it step-by-step. |
# | 1.4 Errors                   | Find and fix bugs in code snippets; explain type of error (logic or syntax). |
# | 1.5 Documentation            | Practice adding comments to uncommented code to explain purpose of each part. |
#
# ---
#
# ## 🔢 Big Idea 2: Data
#
# | Topic                         | What to Practice |
# |------------------------------|------------------|
# | 2.1 Binary Numbers           | Convert binary to decimal and vice versa; identify bit patterns in multiple choice. |
# | 2.2 Data Compression         | Compare lossy/lossless examples in real life (e.g., .mp3 vs .wav). |
# | 2.3 Extracting Info          | Use a sample dataset to identify trends or outliers. |
# | 2.4 Using Data in Programs   | Write a function that stores input in a list and calculates something from it. |
# | 2.5 Impact of Data           | Read an article and list privacy issues or biased impacts of data collection. |
#
# ---
#
# ## 💻 Big Idea 3: Algorithms and Programming
#
# | Topic                         | What to Practice |
# |------------------------------|------------------|
# | 3.1 Variables & Assignment   | Write short programs that manipulate variables in creative ways. |
# | 3.2 Data Abstraction         | Write a program that uses a list to store and update items. |
# | 3.3 Managing Complexity      | Turn long code into functions with parameters. Try practice FRQs that focus on procedures. |
# | 3.4 Developing Algorithms    | Write original algorithms using all 3 components (sequence, selection, iteration). |
# | 3.5 Algorithms               | Compare two sorting/searching methods and explain which is more efficient. |
# | 3.6 Simulations              | Write a basic simulation (e.g., dice rolls or random events). |
# | 3.7 Libraries                | Practice using functions from built-in libraries; read documentation to apply them. |
# | 3.8 Random Values            | Use `random` functions to simulate chance-based behavior in your programs. |
#
# ---
#
# ## 🌐 Big Idea 4: Computer Systems and Networks
#
# | Topic                         | What to Practice |
# |------------------------------|------------------|
# | 4.1 The Internet             | Label parts of a network (IP, DNS, packet, router) and explain how data travels. |
# | 4.2 Fault Tolerance          | Analyze how redundancy and fault tolerance keep the internet running during failures. |
#
# ---
#
# ## 🔐 Big Idea 5: Impact of Computing
#
# | Topic                         | What to Practice |
# |------------------------------|------------------|
# | 5.1 Beneficial & Harmful Effects | Identify both benefits and harms in real-world examples (e.g., accessibility vs addiction). |
# | 5.2 Digital Divide           | Analyze a situation and describe how access to tech could impact different groups. |
# | 5.3 Computing Bias           | Evaluate examples of biased code/data and suggest ways to improve fairness. |
# | 5.4 Crowdsourcing            | Analyze pros/cons of relying on crowdsourced info like Wikipedia or Waze. |
# | 5.5 Legal & Ethical Concerns| Practice identifying ethical and legal violations in computing scenarios. |

# %% [markdown]
# ---
#
# ## 📅 Study Plan: Two Weeks Until the Exam
#
# ### Week 1: Foundation + Practice
# - **Monday–Tuesday**: Review Big Ideas 1 & 2 (Creative Development + Data)
#   - Re-read notes and flashcards
#   - Do 10–15 MCQs on those topics daily
# - **Wednesday–Thursday**: Review Big Idea 3 (Algorithms + Programming)
#   - Practice writing code and tracing logic
#   - Focus on loop + condition problems
# - **Friday**: Do a **full-length MCQ section** (70 questions)
#   - Use AP Classroom or practice exams
# - **Saturday**: Work on **2 practice FRQs**
#   - Focus on clarity and efficiency
# - **Sunday**: Light review + catch up + rest
#
# ### Week 2: Review + Simulate
# - **Monday**: Review Big Idea 4 (Internet/Networks) and 5 (Impact of Computing)
#   - Practice related MCQs and reflect on real-world computing effects
# - **Tuesday–Wednesday**: Mix it up
#   - Alternate MC and FRQ practice (1–2 FRQs daily)
#   - Use College Board’s scoring guidelines to self-grade
# - **Thursday**: Take a full **timed practice exam** (MC + FRQs)
# - **Friday**: Review weak spots + create a 1-page cheat sheet summary
# - **Weekend** (before test): Rest, breathe, and casually glance over notes or flashcards
#
# ---
